# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %% [markdown]
# # Parte 2

# %%
import cv2

# %% [markdown]
# # 3. Para la imagen segmentacion.png analice el histograma de los canales RGB. Segmente algunos de los elementos presentes en la imagen (agua, cielo, tierra) y muestre, aplicando mascaras, las regiones en imágenes separadas.

# %%
img_segmentacion_rgb = cv.imread('/content/drive/MyDrive/Colab Notebooks/VC1/tp1/segmentacion.png', cv.COLOR_BGR2RGB)

# %%
imgRGB = cv.cvtColor(img_segmentacion_rgb, cv.COLOR_BGR2RGB)

plt.figure(1)
plt.imshow(imgRGB)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 imgRGB = cv.cvtColor(img_segmentacion_rgb, cv.COLOR_BGR2RGB)
#       3 plt.figure(1)
#       4 plt.imshow(imgRGB)
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
plt.hist(imgRGB.ravel(),256,[0,256])

# %%
imgRGB.shape
# Out:
# (628, 953, 3)

# %% [markdown]
# # Segmentacion elemento CIELO

# %%
# Tomamos una muestra
img_muestra_cielo = imgRGB[0:250, 0:953,:]
plt.figure()
plt.imshow(img_muestra_cielo)
plt.show()

# %%
# Calculamos el promedio y la dstd de la muestra en los 3 canales
color_mean, color_std = cv.meanStdDev(img_muestra_cielo)
print(color_mean.flatten().tolist())
print(color_std.flatten().tolist())
# Out:
# [57.39733053515216, 150.0451542497377, 217.33684784889823]
# [57.63807958882026, 29.515871927088394, 15.925663175753472]

# %%
# Pintemos de blanco los puntos que estén cerca de la media en un radio menor que 3 sigmas
# para ¨capturar¨ el 99.7 % de pixeles.
n_sigma =2.7
mask = cv.inRange(imgRGB, color_mean-color_std * n_sigma,  color_mean+color_std * n_sigma)
img_segmentada = cv.bitwise_and(imgRGB, imgRGB, mask=mask)

plt.figure()
plt.imshow(img_segmentada)
plt.show()

plt.figure()
plt.imshow(mask,cmap='gray')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Segmentacion elemento Agua

# %%
# Tomamos una muestra
img_muestra_agua = imgRGB[300:400,0:953,:]
plt.figure()
plt.imshow(img_muestra_agua)
plt.show()

# %%
# Calculamos el promedio y la dstd de la muestra en los 3 canales
color_mean_agua, color_std_agua = cv.meanStdDev(img_muestra_agua)
print(color_mean.flatten().tolist())
print(color_std.flatten().tolist())
# Out:
# [57.39733053515216, 150.0451542497377, 217.33684784889823]
# [57.63807958882026, 29.515871927088394, 15.925663175753472]

# %%
# Pintemos de blanco los puntos que estén cerca de la media en un radio menor que 3 sigmas
# para ¨capturar¨ el 99.7 % de pixeles.
n_sigma = 0.7
mask_agua = cv.inRange(imgRGB, color_mean_agua-color_std_agua * n_sigma,  color_mean_agua+color_std_agua * n_sigma)
img_segmentada_agua = cv.bitwise_and(imgRGB, imgRGB, mask=mask_agua)

plt.figure()
plt.imshow(img_segmentada_agua)
plt.show()

plt.figure()
plt.imshow(mask_agua,cmap='gray')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Segmentacion elemento ROCAS

# %%
# Tomamos una muestra
img_muestra_rocas = imgRGB[500:600,0:953,:]
plt.figure()
plt.imshow(img_muestra_rocas)
plt.show()

# %%
# Calculamos el promedio y la dstd de la muestra en los 3 canales
color_mean_rocas, color_std_rocas= cv.meanStdDev(img_muestra_rocas)
print(color_mean.flatten().tolist())
print(color_std.flatten().tolist())
# Out:
# [57.39733053515216, 150.0451542497377, 217.33684784889823]
# [57.63807958882026, 29.515871927088394, 15.925663175753472]

# %%
# Pintemos de blanco los puntos que estén cerca de la media en un radio menor que 3 sigmas
# para ¨capturar¨ el 99.7 % de pixeles.
n_sigma = 1
mask_Rocas = cv.inRange(imgRGB, color_mean_rocas-color_std_rocas * n_sigma,  color_mean_rocas+color_std_rocas * n_sigma)
img_segmentada_Rocas = cv.bitwise_and(imgRGB, imgRGB, mask=mask_Rocas)

plt.figure()
plt.imshow(img_segmentada_Rocas)
plt.show()

plt.figure()
plt.imshow(mask_Rocas,cmap='gray')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # resumen

# %%
figure,ax=plt.subplots(1,3,figsize=(20,10))
ax[0].imshow(img_segmentada)
ax[0].set_title('Cielo')
ax[1].imshow(img_segmentada_agua)
ax[1].set_title('Agua')
ax[2].imshow(img_segmentada_Rocas)
ax[2].set_title('Rocas')
# Out:
# Text(0.5, 1.0, 'Rocas')

# %%
fig, ax=plt.subplots(1,2,figsize=(10,10))
ax[0].imshow(img_segmentacion_rgb)  #  cv2_imshow(img_segmentacion)
ax[1].hist(img_segmentacion.ravel(),256,[0,256])

# %%
hist_img3_0=cv.calcHist(img3,[0],None,[256],[0,256])

# %%
hist_img3_1=cv.calcHist(img3,[1],None,[256],[0,256])

# %%
hist_img3_2=cv.calcHist(img3,[2],None,[256],[0,256])

# %%
plt.figure(figsize=(15, 10))
plt.plot(hist_img3_0, color='r')
plt.plot(hist_img3_1, color='g')
plt.plot(hist_img3_2, color='b')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-92397a70f28c> in <cell line: 0>()
# ----> 1 plt.figure(figsize=(15, 10))
#       2 plt.plot(hist_img3_0, color='r')
#       3 plt.plot(hist_img3_1, color='g')
#       4 plt.plot(hist_img3_2, color='b')
#
# NameError: name 'plt' is not defined
